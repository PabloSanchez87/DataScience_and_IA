# %%
import pandas as pd
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict
from imblearn.over_sampling import SMOTE
import numpy as np
from sklearn.feature_selection import SequentialFeatureSelector
import seaborn as sns

diabetes_df = pd.read_csv('diabetes.csv')

X = diabetes_df[['Glucose','BMI']]
y = diabetes_df['Outcome']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree


# Ajustar el modelo
cdt = DecisionTreeClassifier(max_depth=1)
cdt.fit(X, y)
y_pred = cdt.predict(X)

# Crear una figura con 1 fila y 2 columnas de subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Primer subgráfico: árbol de decisión
feature_names = list(X.columns)
plot_tree(cdt, feature_names=feature_names, ax=axes[0])
axes[0].set_title('Árbol de Decisión')

# Segundo subgráfico: diagrama de dispersión
scatter = axes[1].scatter(X['Glucose'], X['BMI'], c=y_pred, cmap='coolwarm')
axes[1].set_xlabel('Glucose')
axes[1].set_ylabel('BMI')
axes[1].set_title('Diagrama de Dispersión')
plt.colorbar(scatter, ax=axes[1], label='Predicción')

# Ajustar el layout y mostrar la figura
plt.tight_layout()
plt.show()

# %%
# Ajustar el modelo con max_depth=2
cdt = DecisionTreeClassifier(max_depth=2)
cdt.fit(X, y)
y_pred = cdt.predict(X)

# Crear una figura con 1 fila y 2 columnas para dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Primer subgráfico: árbol de decisión
plot_tree(cdt, feature_names=feature_names, ax=axes[0])
axes[0].set_title('Árbol de Decisión (max_depth=2)')

# Segundo subgráfico: diagrama de dispersión
scatter = axes[1].scatter(X['Glucose'], X['BMI'], c=y_pred, cmap='coolwarm')
axes[1].set_xlabel('Glucose')
axes[1].set_ylabel('BMI')
axes[1].set_title('Diagrama de Dispersión (max_depth=2)')
plt.colorbar(scatter, ax=axes[1], label='Predicción')

# Ajustar el layout y mostrar la figura
plt.tight_layout()
plt.show()

# %%
# Ajustar el modelo con max_depth=3
cdt = DecisionTreeClassifier(max_depth=3)
cdt.fit(X, y)
y_pred = cdt.predict(X)

# Crear una figura con 1 fila y 2 columnas para dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Primer subgráfico: árbol de decisión
plot_tree(cdt, feature_names=feature_names, ax=axes[0])
axes[0].set_title('Árbol de Decisión (max_depth=3)')

# Segundo subgráfico: diagrama de dispersión
scatter = axes[1].scatter(X['Glucose'], X['BMI'], c=y_pred, cmap='coolwarm')
axes[1].set_xlabel('Glucose')
axes[1].set_ylabel('BMI')
axes[1].set_title('Diagrama de Dispersión (max_depth=3)')
plt.colorbar(scatter, ax=axes[1], label='Predicción')

# Ajustar el layout y mostrar la figura
plt.tight_layout()
plt.show()

# %%
# Ajustar el modelo con max_depth=4
cdt = DecisionTreeClassifier(max_depth=4)
cdt.fit(X, y)
y_pred = cdt.predict(X)

# Crear una figura con 1 fila y 2 columnas para dos subgráficos
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Primer subgráfico: árbol de decisión
plot_tree(cdt, feature_names=feature_names, ax=axes[0])
axes[0].set_title('Árbol de Decisión (max_depth=4)')

# Segundo subgráfico: diagrama de dispersión
scatter = axes[1].scatter(X['Glucose'], X['BMI'], c=y_pred, cmap='coolwarm')
axes[1].set_xlabel('Glucose')
axes[1].set_ylabel('BMI')
axes[1].set_title('Diagrama de Dispersión (max_depth=4)')
plt.colorbar(scatter, ax=axes[1], label='Predicción')

# Ajustar el layout y mostrar la figura
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
